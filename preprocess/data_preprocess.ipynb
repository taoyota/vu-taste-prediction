# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
bitterdb_df = pd.read_csv("../data/BitterCompoundsPropA_2024.csv")

# %%
bitterdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2250 entries, 0 to 2249
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   cid                      2250 non-null   int64
#  1   cStruc                   2250 non-null   object
#  2   canonical_smiles         2250 non-null   object
#  3   Isomeric_smiles          2250 non-null   object
#  4   pubChemID                1837 non-null   float64
#  5   IUPAC                    1761 non-null   object
#  6   cFormula                 2250 non-null   object
#  7   InChiKey                 2250 non-null   object
#  8   MW                       2250 non-null   float64
#  9   AlogP                    2250 non-null   float64
#  10  Num_AromaticRings        2250 non-null   int64
#  11  Num_H_Acceptors          2250 non-null   int64
#  12  Num_H_Donors             2250 non-null   int64
#  13  Num_RotatableBonds       2250 non-null   int64
# ...

# %%
bitterdb_df.head()
# Out:
#    cid                                             cStruc  \
# 0    7  COC1=CC2=C(C=CN=C2C=C1)C(C3CC4CCN3CC4C=C)O.OS(...
# 1    9     COC1=CC2=C(C=CN=C2C=C1)C(C3CC4CC[NH+]3CC4C=C)O
# 2   11  CC(C)CC(=O)C1=C(C(C(=O)C(C1=O)CC=C(C)C)(CC=C(C...
# 3   14  COC1=CC2=C(C=CN=C2C=C1)C(C3CC4CCN3CC4C=C)O.COC...
# 4   15                                   C1=CC=C(C=C1)C=O
#
#                                     canonical_smiles  \
# 0  COC1=CC2=C(C=CN=C2C=C1)C(C3CC4CCN3CC4C=C)O.OS(...
# 1     COC1=CC2=C(C=CN=C2C=C1)C(C3CC4CC[NH+]3CC4C=C)O
# 2  CC(C)CC(=O)C1=C(C(C(=O)C(C1=O)CC=C(C)C)(CC=C(C...
# 3  COC1=CC2=C(C=CN=C2C=C1)C(C3CC4CCN3CC4C=C)O.COC...
# 4                                   C1=CC=C(C=C1)C=O
#
#                                      Isomeric_smiles   pubChemID  \
# 0  COC1=CC2=C(C=CN=C2C=C1)C(C3CC4CCN3CC4C=C)O.OS(...     11069.0
# 1  COC1=CC2=C(C=CN=C2C=C1)[C@H]([C@@H]3C[C@H]4CC[...  11920271.0
# 2  CC(C)CC(=O)C1=C(C(C(=O)C(C1=O)CC=C(C)C)(CC=C(C...    160467.0
# ...

# %%
bitterdb_df.isnull().sum()
# Out:
# cid                           0
# cStruc                        0
# canonical_smiles              0
# Isomeric_smiles               0
# pubChemID                   413
# IUPAC                       489
# cFormula                      0
# InChiKey                      0
# MW                            0
# AlogP                         0
# Num_AromaticRings             0
# Num_H_Acceptors               0
# Num_H_Donors                  0
# Num_RotatableBonds            0
# Num_Rings                    29
# isNatural                  1886
# ExpVal                     1742
# SensoryThr                    0
# toxicity_val                  0
# pubChemSid                 2144
# AminoAcidSeq               1759
# comment                    1998
# Cas_Number_Final           1462
# Human                         0
# Chicken                       0
# Mouse                         0
# Cat                           0
# related_pubChemID          2220
# more_identifiers           2058
# ...

# %%
chemtastedb_df = pd.read_excel("../data/ChemTastesDB_database.xlsx",
                               na_values=["*"],
                               keep_default_na=True)
print(chemtastedb_df.info())
chemtastedb_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4078 entries, 0 to 4077
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    4075 non-null   object
#  1   Name                  4077 non-null   object
#  2   PubChem CID           2383 non-null   float64
#  3   CAS number            1641 non-null   object
#  4   canonical SMILES      4075 non-null   object
#  5   Taste                 4075 non-null   object
#  6   Class taste           4075 non-null   object
#  7   Reference_(cod)/[pp]  4075 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 255.0+ KB
# None
#      ID                                      Name  PubChem CID   CAS number  \
# 0  0001                          (-)-Haematoxylin     320930.0     517-28-2
# 1  0002                (+)-4β-hydroxyhernandulcin     126862.0  145385-64-4
# ...

# %%
chemtastedb_df.isnull().sum()
# Out:
# ID                         3
# Name                       1
# PubChem CID             1695
# CAS number              2437
# canonical SMILES           3
# Taste                      3
# Class taste                3
# Reference_(cod)/[pp]       3
# dtype: int64

# %%
taste_count = chemtastedb_df["Class taste"].value_counts(dropna=False)

# %%
ax = taste_count.plot(kind="bar", title="Taste Distribution")

for i, count in enumerate(taste_count):
    ax.text(i, count, str(count), ha="center", va="bottom")

ax.set_xlabel("Taste Categories")
ax.set_ylabel("Count")
ax.set_xticklabels(taste_count.index.fillna("NA"), rotation=45)

plt.show()

# %%
pubchemid_na_count = chemtastedb_df["PubChem CID"].isna().sum()
total_entries = len(chemtastedb_df)

labels = ["Valid PubChemCid", "Missing"]
sizes = [total_entries - pubchemid_na_count, pubchemid_na_count]
explode = (0, 0.1)

plt.pie(sizes, explode=explode, labels=labels, startangle=90, autopct='%1.1f%%',
        textprops={'fontsize': 12})
plt.axis('equal')
plt.title('PubChemCID Completeness')
plt.show()
