# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors

# %%
def get_features(smiles):
    mol = Chem.MolFromSmiles(smiles)

    if mol is None:
        return None

    features = {"MW": Descriptors.MolWt(mol)}

    return features

# %%
def is_peptide(smiles):
    mol = Chem.MolFromSmiles(smiles)

    amide_linkage = Chem.MolFromSmarts("C(=O)N")
    if not mol.HasSubstructMatch(amide_linkage):
        return False

    amino_acid_count = Chem.MolFromSmarts("[NX3][CX4H][CX3](=O)")  # Generic AA
    aa_matches = mol.GetSubstructMatches(amino_acid_count)
    return len(aa_matches) >= 2

# %%
chemtaste_df = pd.read_csv(r"chemtastes_families.csv")

chemtatste_descriptors = chemtaste_df["smiles"].apply(get_features).apply(pd.Series)
chemtaste_df = chemtaste_df.join(chemtatste_descriptors).dropna()

chemtaste_df.head()
# Out:
#                                               smiles      taste  \
# 0             Oc1cc2c(cc1O)C1c3ccc(c(c3OCC1(O)C2)O)O  Sweetness
# 1                  CC(C)=CCCC(C)(O)C1CC(O)C(=CC1=O)C  Sweetness
# 2      CC(=O)OC1C(Oc2cc(cc(c2C1=O)O)O)c1ccc(c(c1)O)O  Sweetness
# 3  COc1c(cc2c(c1O)C(=O)C(OC(C)=O)C(O2)c1ccc(c(c1)...  Sweetness
# 4  COc1ccc(cc1O)C1Cc2cccc(c2C(=O)O1)OC1OC(CO)C(O)...  Sweetness
#
#                          superclass                   class  \
# 0      Organoheterocyclic compounds             Benzopyrans
# 1   Lipids and lipid-like molecules           Prenol lipids
# 2  Phenylpropanoids and polyketides              Flavonoids
# 3  Phenylpropanoids and polyketides              Flavonoids
# 4          Organic oxygen compounds  Organooxygen compounds
#
#                                     subclass       MW
# 0                              1-benzopyrans  302.282
# 1                           Sesquiterpenoids  252.354
# 2                                    Flavans  346.291
# 3                    O-methylated flavonoids  376.317
# 4  Carbohydrates and carbohydrate conjugates  448.424

# %%
chemtaste_mw_sorted = chemtaste_df.sort_values(by="MW", ascending=False)
chemtaste_peptides = chemtaste_mw_sorted[chemtaste_mw_sorted['MW'] <= 500] # 

print(len(chemtaste_peptides))
chemtaste_peptides
# Out:
# 2932
#                                                  smiles          taste  \
# 1462  CCN1CC2(COC)C(O)CC(OC)C34C5CC6(O)C(O)C5C(O)(C(...     Bitterness
# 1703  CC1C2C(CC3(C)C4CC=C5C(C=C(O)C(=O)C5(C)C)C4(C)C...     Bitterness
# 925   COC(=O)C(CSC(C)(C)C)NC(=O)C(CC(O)=O)NCCC(C)(C)...      Sweetness
# 2564  CC1(O)CC23CCC4C(C)(CCCC4(C)C(O)=O)C3CCC1(C2)OC...     Bitterness
# 3207  CC12CCCC(C)(C2CCC23CC(CCC12)C(O)(CO)C3)C(=O)OC...  Tastelessness
# ...                                                 ...            ...
# 3014                                       [NH4+].[Cl-]      Saltiness
# 3332                                                CCO  Non-sweetness
# 2980                                               OC=O       Sourness
# 2983                                                 Cl       Sourness
# 1990                                                 OO     Bitterness
#
# 923   Amino acids, peptides, and analogues  492.613
# 2865  Amino acids, peptides, and analogues  487.554
# 230   Amino acids, peptides, and analogues  487.534
# 2459  Amino acids, peptides, and analogues  486.582
# ...                                    ...      ...
# 2228  Amino acids, peptides, and analogues  186.211
# 1635  Amino acids, peptides, and analogues  184.239
# 1636  Amino acids, peptides, and analogues  184.239
# 1640  Amino acids, peptides, and analogues  170.212
# 1638  Amino acids, peptides, and analogues  168.196
#
# [474 rows x 6 columns]

# %%
chemtaste_non_peptides = chemtaste_df[~chemtaste_df.isin(chemtaste_peptides_true.to_dict("list")).all(axis=1)]
chemtaste_non_peptides
# Out:
#                                                  smiles           taste  \
# 0                Oc1cc2c(cc1O)C1c3ccc(c(c3OCC1(O)C2)O)O       Sweetness
# 1                     CC(C)=CCCC(C)(O)C1CC(O)C(=CC1=O)C       Sweetness
# 2         CC(=O)OC1C(Oc2cc(cc(c2C1=O)O)O)c1ccc(c(c1)O)O       Sweetness
# 3     COc1c(cc2c(c1O)C(=O)C(OC(C)=O)C(O2)c1ccc(c(c1)...       Sweetness
# 4     COc1ccc(cc1O)C1Cc2cccc(c2C(=O)O1)OC1OC(CO)C(O)...       Sweetness
# ...                                                 ...             ...
# 3553  CC(CCC(O)C(C)(C)O)C1CCC2(C)C3CC=C4C(CCC(O)C4(C...  Non-bitterness
# 3554                                  OCC(O)C(O)C(=O)CO  Non-bitterness
# 3555                      CC1OC(C)C(OS(O)(=O)=O)C(O)C1O  Non-bitterness
# 3556  CC(=O)OC(C)(C)C1Cc2cc3c(cc2O1)OC(=O)C(=C3)C(C)...  Non-bitterness
# 3557                           OCC(O)C(O)C(O)C(O)C(O)CO  Non-bitterness
#
#                             superclass                             class  \
# 0         Organoheterocyclic compounds                       Benzopyrans
# 1      Lipids and lipid-like molecules                     Prenol lipids
# 2     Phenylpropanoids and polyketides                        Flavonoids
# 3     Phenylpropanoids and polyketides                        Flavonoids
# 4             Organic oxygen compounds            Organooxygen compounds
# ...                                ...                               ...
# 3553   Lipids and lipid-like molecules  Steroids and steroid derivatives
# 3554          Organic oxygen compounds            Organooxygen compounds
# 3555      Organoheterocyclic compounds                            Oxanes
# 3556  Phenylpropanoids and polyketides         Coumarins and derivatives
# 3557          Organic oxygen compounds            Organooxygen compounds
#
#                                        subclass       MW
# 0                                 1-benzopyrans  302.282
# 1                              Sesquiterpenoids  252.354
# 2                                       Flavans  346.291
# 3                       O-methylated flavonoids  376.317
# 4     Carbohydrates and carbohydrate conjugates  448.424
# ...                                         ...      ...
# 3553                              Cucurbitacins  474.726
# 3554  Carbohydrates and carbohydrate conjugates  150.130
# 3555                                    Unknown  242.249
# 3556                            Furanocoumarins  356.418
# 3557  Carbohydrates and carbohydrate conjugates  212.198
#
# [2984 rows x 6 columns]

# %%
# chemtaste_non_peptides.head()

# %%
chemtaste_non_peptides.to_csv('ChemTaste_nonpeptides.csv', index=False)
